# %%
#import numpy for generating random numbers
import numpy as np
#import matplotlib library
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
#generate random numbers (total 10)
randomNumber = np.random.rand(10)

# %%
#view them
print randomNumber
# Out:
# [0.16244389 0.30009171 0.30165532 0.49115671 0.06575911 0.83960356
#  0.50488528 0.61498172 0.58665961 0.29390353]

# %%
#select the style of the plot
style.use('ggplot')
#plot the random number
plt.plot(randomNumber,'g',label='line one',linewidth=2)
#x axis is number of random numbers (index)
plt.xlabel('Range')
#y axis is actual random number
plt.ylabel('Numbers')
#title of the plot
plt.title('First plot')
# Out:
# Text(0.5,1,'First plot')

# %%
plt.legend()
plt.show()
